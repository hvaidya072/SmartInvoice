# %% [markdown]
# # Detecting edges in text

# %%
import cv2
import numpy as np
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\Staff201\AppData\Local\Tesseract-OCR\tesseract.exe'

# %%
img = cv2.imread('1.jpg')
# img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img, cmap='gray')

# %%
def display(img, cmap=None):
    fig = plt.figure(figsize=(10,15))
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap=cmap)

display(img, cmap='gray')

# %%
def preprocess(img):
    rgb = cv2.pyrDown(img)
    img = cv2.cvtColor(rgb, cv2.COLOR_BGR2GRAY)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
    grad = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
#     display(grad, cmap='gray')
    ret, thresh = cv2.threshold(grad, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    kernel_rect = cv2.getStructuringElement(cv2.MORPH_RECT, (19,3))
    connected = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel=kernel_rect)
#     display(connected, cmap='gray')
    ker = np.ones((11,11), dtype=np.uint8)
    dilated = cv2.dilate(connected, kernel=ker)
#     display(diluted, cmap='gray')
    
    contours, hierarchy = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    print(len(contours))
    
    mask = np.zeros(thresh.shape, dtype=np.uint8)
#     display(mask, cmap='gray')
    
    for idx in range(len(contours)):
        x,y,w,h = cv2.boundingRect(contours[idx])
        mask[y:y+h, x:x+w] = 0
        cv2.drawContours(mask, contours, idx, (255, 255, 255), -1)
        r = float(cv2.countNonZero(mask[y:y+h, x:x+w])) / (w * h)
        
        if r >0.45 and w > 8 and h > 8:
            tex = pytesseract.image_to_string(img[y:y+h, x:x+w])
#             ro = img[y-4:y+h+4, x-4:x+w+4]
#             display(ro, cmap='gray')
            cv2.rectangle(rgb, ((x),(y)), (x+(w),y+(h)), (0,255,0), 2)
            print(tex)
    display(rgb, cmap='gray')
#     return contours

# %%
def preprocess2(img, rect_kernel=(9,3)):
#     rgb = cv2.pyrDown(img)
    rgb = img.copy()
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
    grad = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
#     display(grad, cmap='gray')
    ret, thresh = cv2.threshold(grad, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, rect_kernel)
    connected = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel=kernel)
#     display(connected, cmap='gray')
    ker = np.ones((17,17), dtype=np.uint8)
    dilated = cv2.dilate(connected, kernel=ker)
    display(dilated)
    
    contours, hierarchy = cv2.findContours(dilated.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
    print(len(contours))
    
    mask = np.zeros(thresh.shape, dtype=np.uint8)
#     display(mask, cmap='gray')
    
    for idx in range(len(contours)):
        x,y,w,h = cv2.boundingRect(contours[idx])
        mask[y:y+h, x:x+w] = 0
        cv2.drawContours(mask, contours, idx, (255, 255, 255), -1)
        r = float(cv2.countNonZero(mask[y:y+h, x:x+w])) / (w * h)
        
        if r >0.45 and w > 8 and h > 8:
            tex = pytesseract.image_to_string(img[y:y+h, x:x+w])
            ro = img[y:y+h, x:x+w]
#             display(ro, cmap='gray')
            cv2.rectangle(rgb, (x,y), (x+w,y+h), (0,255,0), 2)
            print(tex)
    display(rgb, cmap='gray')
    return contours

# %%
cnts = preprocess2(img)
# Out:
# 183
#
#
#
#
#
#
# For R.G.M.C INTERNATIONAL
# TERMS & CONDITIONS :
#
# 1, Subject to Amritsar Jurisdiction.
#
# 2, Goods once sold are not returnable.
#
# 3, Bill not paid on presentation will be subject to Interest @24% p.a.
#
# 4, Our Risk & Responsibility ceases as soon as the goods leave our premises.
# 5. Please do not deposit cash in our account.
#
# (Inclusive of
# all taxes)
#
# PNB A/C NO.0520002100132024 IFSC:PUNB0052000
# J & K BANK A/C NO. 0056010100005323 IFSC: JAKAOGURUJI
# ICICI BANK A/C NO. 006605500530 IFSC: ICIC0000066
# PNB A/C NO.0520002100132024 IFSC: PUNB0052000
# J & K BANK A/C NO. 0056010100005323 IFSC: JAKAOGURUJI (Inclusive of
# ICICI BANK A/C NO. 006605500530 IFSC: ICIC0000066 all taxes)
#
# NET AMOUNT
#
# 22050.00
# ONLY
# FIFTY
# TWENTY TWO THOUSAND
#
#
#
#
# 3
# LUDHIANA
#
#
# 1050.00
#
#
# PVT.BALE NO.
#
# 1329/3
#
# TOTAL =
#
# 105 TOTAL
#
# TOTAL GST
#
# NET AMOUNT
#
# il
#
# 21000.00
#
# 1050.00
#
# 22050.00
# 525.00
# 525.00
# 02/01/2018 ;~—
# TOTALS----- >
#
# SURJIT GOODS CARRIERS
#
# 34696 Dated:
# Frgt :
#
# 3 Weight
# RCM : NO TOTALS----- > 525.00
#
# Transport : SURJIT GOODS CARRIERS 525.00
#
# GR No. : 34696 Dated: 02/01/2018
#
# Vehicle No: Frgt : PVT.BALE NO.
# T.Bales : 3 Weight 1329/3
#
#
#
# Doc.Thru. : LUDHIANA
#
# RS. TWENTY TWO THOUSAND FIFTY ONLY
#
#
#
#
#
#
#
# A
#
# 21000.00
# 200.00
# 105.00
#
# .
# noe
#
#
#
#
# 6301
#
# %
# BLANKETS
# SNOW BEAR
#
# RCM : N
#
# Amount
# (In Rs.)
# Amount
# (In Rs.)
# Qty.
# Qty.
#
# SGST
# Description of Goods
# HSN/
# SAC
# Description of Goods
#
#
#
# STATE
# PB-03
#
# ADHAR:
# PH
#
# PAN :
# Broker
# PARSHOTAM AND ASSOCIATES ADHAR:
# 10-B,UDHAM SINGH NAGAR PH : 9876445400
# CIVIL LINES LUDHIANA 141001
#
# PAN : AAIFP6230H
# GSTIN: O3AAIFP6230H12ZH STATE : PB-03 Broker : DIRECT
#
# Dated
# CREDIT
# R1329
# Invoice No.:
# Invoice No.: R1329 CREDIT Dated : 02/01/2018
# Invoice No.: R1329 CREDIT : 02/01/2018
#
# PARSHOTAM AND ASSOCIATES :
#
# 10-B,UDHAM SINGH NAGAR : 9876445400
# CIVIL LINES LUDHIANA 141001 PAN : AAIFP6230H
# GSTIN: O3AAIFP6230H12ZH STATE : PB-03 Broker : DIRECT
#
# 1/ BLANKETS
# SNOW BEAR
#
#
#
# —I|RCM : NO TOTALS----- > 525.00 105 TOTAL = 21000.00
# Transport : SURJIT GOODS CARRIERS 525.00
# ~~|GR No. : 34696 Dated: 02/01/2018
#
# Vehicle No: Frgt : PVT.BALE NO. TOTAL GST
# T.Bales : 3 Weight 1329/3
# Doc. Thru. : LUDHIANA
#
# 1050.00
#
#
#
# RS. TWENTY TWO THOUSAND FIFTY ONLY
# 22050.00
#
# PNB A/C NO.0520002100132024 IFSC: PUNB0052000
# J & K BANK A/C NO. 0056010100005323 IFSC: JAKAOGURUJI (Inclusive of
# ICICI BANK A/C NO. 006605500530 IFSC: ICIC0000066 all taxes)
#
# R.G.M.C INTERNATIONAL
# 4,G.T.ROAD,OPPOSITE MODEL TOWN, AMRITSAR
# Email Id: rgmcintl@gmail.com
# MB
# (OFFICE) 098774-20089
# MB.098729-69709
# STATE CODE/POS : 03
# GSTTUSAAOPP0960A123
# ADHAR: 4878-7305-5464
# Original
# for Buyer/Receipent
# TAX INVOICE

# %%
cnts_de = preprocess(img)
# Out:
# 14
#
#
#
#
#
#
#
#
# Invoice No.: R1329 CREDIT Dated : 02/01/2018
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PARSHOTAM AND ASSOCIATES ADHAR:
# 10-B,UDHAM SINGH NAGAR PH 3 9876445400
# CIVIL LINES LUDHIANA 141001 PAN AAIFP6230H
# GSTIN: O3AATFP6230H12H STATE : PB-03 | Broker : DIRECT
# 8.| Description of Goods sw/ | scst| cost| 1cst|Bags| ty. Rate | Amount
# No ‘SAC s s s (In Rs.)| (In Rs.)
# 1/BLANKETS 6301 2.50] 2.50 105.00 200.00) 21000.00
# SNOW BEAR
# ¥] ol
# wail! Me oe
#
#
#
#
#
#
#
#
#
#
#
# ROM: N
# RCM: NO ‘TOTALS 525.00 105 TOTAL = —-21000.00
# Transport : SURJIT GOODS CARRIERS 525.00
# IGR No. 34696 Dated: 02/01/2018
# Wehicle Ni Frgt TOTAL GST = 1050.00
# T.Bales : 3 Weight
# Doc.Thru. : LUDHIANA
# RS. TWENTY TWO THOUSAND FIFTY ONLY _——
#
# NET AMOUNT = — 22050.00
#
#
#
# PNB A/C NO.0520002100132024 IFSC:PUNBO052000
#
#
#
#
#
#
#
#
#
# J & K BANK A/C NO. 0056010100005323 IFSC: JAKAOGURUJI (Inclusive of
# ICICI BANK A/C NO, 006605500530 IFsc: Icrco000066 all taxes)
# TERMS & CONDITIONS : For R.G.M.C INTERNATIONAL
# 1. Subject to Aaritear Jurisdiction
# 2, Goods cace sold are not returable
# 4. BAL not puid on presentaticn vill be subject to Interest #244 pia.
#
# 4. Oar Risk & Hespensibility ceases as seen as the goods Leave car prises.
# 5. Please do not deposit cash in our account.
# R-G.M.C INTERNATIONAL
# 4,G.T.ROAD, OPPOSITE MODEL TOWN, AMRITSAR
# Email Id: rgmcint1@gmail.com
# MB (OFFICE) 098774-20089
# MB.098729-69709
# STATE CODE/POS : 03
# GercOTRAOPPOSEOALZ3
# ‘ADHAR: 4878-7305-5464
# Original for Buyer/Receipent
# TAX INVOICE

# %%
# def detection(img,contours):
#     mask = np.zeros(img.shape[:2], dtype=np.uint8)
#     for idx in range(len(contours)):
#         x,y,w,h = cv2.boundingRect(contours[idx])
#         mask[y:y+h, x:x+w] = 0
#         cv2.drawContours(mask, contours, idx, (255, 255, 255), -1)
#         r = float(cv2.countNonZero(mask[y:y+h, x:x+w])) / (w * h)
        
#         if r >0.45 and w > 8 and h > 8:
#             roi = img[y:y+h, x:x+w]
#             display(roi, cmap='gray')

# %%
img1 = cv2.imread('2.jpg')

# %%
display(img1)

# %%
img1_cnts = preprocess2(img1)
# Out:
# 158
# Thic ic an electronically nanaratad céatareanm® med hmmm ek
#
# signature & stamp
#
# airtel outlet _
# cash received
#
# ————$—<—— —— parey date a
#
#
# amount &
# bank / branch
# cheque/dd/payorder no
# amount due: 1,532.64
#
# to make payments,kindly make crossed cheque/dd/pay order in favour of “airtel relationship no 14003364"
# 14003364
# LL
#
# airtel Showrooms
#
# airtel own retail store at scf 42, kipps market, sarabha nagar, Lud is now
# available
#
# airtel own retail store at shop no: 201, bharti pavilion mall, Lud is now
# available.
# -
# Pay on the go
# * Pay using my airtel app. Text MYAIRTEL to 54321
#
# * Pay instantly using Airtel Money app. Download from Play Store / App Store
# * Log onto www.airtel.in and click on ‘pay my bills’
#
# eal
# Pay on the go airtel Showrooms
#
# * Pay using my airtel app. Text MYAIRTEL to 54321
# * Pay instantly using Airtel Money app. Download from Play Store / App Store
# * Log onto www.airtel.in and click on ‘pay my bills’
#
# airtel own retail store at scf 42, kipps market, sarabha nagar, Lud is now
# available
#
# airtel own retail store at shop no: 201, bharti pavilion mall, Lud is now
# available.
# please detach this slip and return with payment
#
#
# Varun Saini, General Manager
#
#
#
#
#
# Ser Bharti Airtel Limited
#
# Bs Zar
#
#
#
#
#
#
# As per the Government directive, effective 1-July-17, existing service tax of 15%
# has been replaced with 18% GST.
#
#
# 1,532.82
#
# this month's charges feriste
#
# In words : One Thousand Five Hundred Thirty Two rupees Eighty Two Palisa.
# eboe.
# Visit airtel.inA/myhome
#
#
#
#
#
# taxes
# BROADBAND DATA WITH
# EVERY AIRTEL POSTPAID
# & DTH CONNECTION
# 1,299.00
# 233.82
# net charges
#
#
# aeee
#
# aS For
# 1,526.40
# 227.40
# gross charges
# less total discounts
#
# 0.00
# 0.00
# GET
# 10 GB/MONTH
# FREE
# Stan nts
#
# Sean
#
# 0.00
#
#
# 1,299.00
# 227.40
# wits pat
#
# ws ms TE
# monthly charges
# ~__all and vas charges
# dsl usage charges
# other charges
#
# late fee
#
#
#
# fen nds san
# this month's charges
#
#
#
#
#
#
#
#
#
#
# 1,532.82
# 0.00
# 1533.00
#
# 1,532.82
#
#
#
#
#
#
# amount due after
# 06-Feb-2018
# 1,650.64
# this month's charges amount due on or»)
# before 06-Feb-2018
# + 1,532.82 =| (1,532.64
# adjustments
# payments
#
#
# previous balance
#
#
#
#
#
#
# 17-Dec-2017
# fie first
#
#
# 01614640500
#
# 01614640500_dsl
# 14003364
# 870117299
# 18-Jan-2018
# telephone number
# user id
# relationship no:
# bill no:
#
# bill date :
#
# billing period :
# paybydate —fifef
#
# M/S PARSHOTAM AND ASSOCIATES
# 10B
#
# Udham Singh Nagar
# Civil Lines
# Ludhiana
#
# Punjab 141001
# fixedline and broadband services
# Original Copy for Recipient - Tax Invoice
# PM airtet

# %%
img2 = cv2.imread('3.jpg')
display(img2)

# %%
preprocess(img2)
# Out:
# 46
#
#
#
#
#
#
# ¢
#
#
#
#
#
#
#
#
#
#
#
# te eter
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘quo uoHRIpsun eveRYpN 01 oalgns Ove SOINGSHP YZ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Pry
#
#
#
#
#
# yd WY B1OZ/TO/TT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8T0Z/T0/zz aaiva | HZTHOEZodaIv¥EO
# e60t00 ‘ON
# 060S2-0r 1860 ah 100 LL - WNVIHGN1 "SANIT TIAID "MMOHO Nd VINOWOG
# €LE0LLZ-1910 4
# coxeisio aca = ©AOUCHD BulsiyeAPO SOUDAPD
#
# {2OUOAPO 10} pongyos 5} yoam e UKM Ina Sin BuIKed snk jo unoNe} OWL“ -@N|
# ATUO ETS AFUBTT Peapunyy SUTN Puy seedny
# W1oL’9
# Xvi 3010835, “OS*Z @| LSDO ‘0
# WLOL xOS*Z @| LSOS
#
#
#
#
#
#
#
#
#
# BOIOANI
#
#
#
#
#
#
#
# >

# %%
cv2.imwrite('new_img.jpg',img)
# Out:
# True

# %%
bhatinda = cv2.imread('bhatinda.jpg')

# %%
cntb = preprocess(bhatinda)
# Out:
# 3
# This is a Computer Generated Invoice
# PARSHOTAM & ASSOCIATES Invoice No.
# 10-B UDHAM SINGH NAGAR }233_______—‘ia-Mar-2018 _|
# LUDHIANA Delivery Note Mode/Terms of Payment
# GSTINIUIN: 03AAIFP6230H1ZH po
# State Name : Punjab, Code : 03 Supplier's Ret. Other Reference(s)
# E-Mail: INFO@PARSHOTAMANDASSOCIATES.COM cam charges
# Buyer's Order No. Dated
# Buyer
# HDFC BANK BATHINDA BRANCH | eopetch Document Na. [Delivery Note Dats
# BATHINDA
# GSTINIUIN — : 03AAACH2702H1ZA |Deepstched trough |Deetnation
# State Name: Punjab, Code : 03, me
# Terms of Delivery
# 8 Particulars HSN/SAC | GST | Quantity | Rate | per! — Amount
# ny Rate
# 1 Professional Charges (998221) 998221 | 18% 74,350.00
# ‘Cam Charges Feb 2018
# 2 cost 6,691.50
# 3 SST 6,691.50
# Total % 87,733.00
# Aunt Chargeable (words) E40E
# Indian Rupees Eighty Seven Thousand Seven Hundred Thirty Three Only
# HSN/SAC Taxable Central Tax State Tax Total
# Value [Rate | Amount | Rate | Amount [Tax Amount
#
# 998221 74,350.00 9%|  6691.50| 9%| 6,691.50 | 13,383.00
#
# Totall 74,350.00 6,691.50 6,691.50 | 13,383.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘Tax Amount (n words) : Indian Rupees Thirteen Thousand Three Hundred Eighty Three Only
#
# Company's PAN : AAIFP6230H
#
#
#
# ‘Company's Bank Details
# Bank Name HDFC BANK
# ‘Alc No. (0034235001576
#
# Branch & FS Code: MALL ROAD & HDFC0000034
#
# {for PARSHOTAM & ASSOCIATES
#
# ‘Authorised Signatory
# Tax Invoice
